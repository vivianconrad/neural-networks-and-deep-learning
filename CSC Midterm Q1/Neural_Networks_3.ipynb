# %% [markdown]
# ## Gradient Descent
# - weight = 0.3
# - input_score = 0.3
# - ground_truth_prediction = 0.4
# - iteration in range(20)
#
# ## Calculation of Gradient Descent
# - square_error = (neural_network_prediction - ground_truth_prediction ) ** 2
# - direction_and_amount = (neural_network_prediction - ground_truth_prediction ) * input
# - weight = weight - direction_and_amount
#
# **Prediction: 0.3483407439059841**

# %%
weight = 0.3
input_score = 0.3
ground_truth_prediction = 0.4

for iteration in range(200):
    neural_network_prediction = input_score * weight
    square_error = (neural_network_prediction - ground_truth_prediction ) ** 2

    direction_and_amount = (neural_network_prediction - ground_truth_prediction ) * input_score
    weight = weight - direction_and_amount

    print("Error:" + str(square_error) + " Prediction: " + str(neural_network_prediction))
# Out:
# Error:0.09610000000000003 Prediction: 0.09
# Error:0.07958041 Prediction: 0.1179
# Error:0.06590053752100002 Prediction: 0.143289
# Error:0.054572235121140115 Prediction: 0.16639299
# Error:0.045191267903816126 Prediction: 0.1874176209
# Error:0.03742288895115014 Prediction: 0.206550035019
# Error:0.030989894340447435 Prediction: 0.22396053186728998
# Error:0.02566273150332452 Prediction: 0.2398040839992339
# Error:0.021251307957903046 Prediction: 0.2542217164393028
# Error:0.01759820811993951 Prediction: 0.26734176195976556
# Error:0.014573076144121903 Prediction: 0.2792810033833867
# Error:0.01206796435494735 Prediction: 0.2901457130788819
# Error:0.009993481282331898 Prediction: 0.3000325989017825
# Error:0.00827560184989905 Prediction: 0.30902966500062207
# Error:0.0068530258919014065 Prediction: 0.31721699515056606
# Error:0.005674990741083551 Prediction: 0.32466746558701515
# Error:0.004699459832691294 Prediction: 0.33144739368418374
# ...

# %% [markdown]
# ## Limitations of Gradient Descent
#
# - weight = 0.3
# - input_score = 2
# - ground_truth_prediction = 0.4
# - iteration in range(20)
#
# ## Calculation of Gradient Descent
# - square_error = (neural_network_prediction - ground_truth_prediction ) ** 2
# - direction_and_amount = (neural_network_prediction - ground_truth_prediction ) * input
# - weight = weight - direction_and_amount
#
# **Prediction: -232452293.0**

# %%
weight = 0.3
input_score = 2
ground_truth_prediction = 0.4

for iteration in range(20):
    neural_network_prediction = input_score * weight
    square_error = (neural_network_prediction - ground_truth_prediction ) ** 2

    direction_and_amount = (neural_network_prediction - ground_truth_prediction ) * input_score
    weight = weight - direction_and_amount

    print("Error:" + str(square_error) + " Prediction: " + str(neural_network_prediction))
# Out:
# Error:0.03999999999999998 Prediction: 0.6
# Error:0.3599999999999998 Prediction: -0.19999999999999984
# Error:3.2399999999999993 Prediction: 2.1999999999999997
# Error:29.160000000000004 Prediction: -5.0
# Error:262.4400000000001 Prediction: 16.6
# Error:2361.960000000001 Prediction: -48.20000000000001
# Error:21257.640000000003 Prediction: 146.20000000000002
# Error:191318.75999999998 Prediction: -437.0
# Error:1721868.8399999996 Prediction: 1312.6
# Error:15496819.559999995 Prediction: -3936.1999999999994
# Error:139471376.04 Prediction: 11810.199999999999
# Error:1255242384.3600001 Prediction: -35429.0
# Error:11297181459.240002 Prediction: 106288.6
# Error:101674633133.16006 Prediction: -318864.20000000007
# Error:915071698198.4406 Prediction: 956594.2000000003
# Error:8235645283785.965 Prediction: -2869781.000000001
# Error:74120807554073.66 Prediction: 8609344.600000001
# Error:667087267986662.9 Prediction: -25828032.200000003
# Error:6003785411879964.0 Prediction: 77484098.2
# ...

# %%
#@title
weight = 0.3
input_score = 2
ground_truth_prediction = 0.4

for iteration in range(20):
    neural_network_prediction = input_score * weight
    square_error = (neural_network_prediction - ground_truth_prediction ) ** 2

    direction_and_amount = (neural_network_prediction - ground_truth_prediction ) * input_score
    weight = weight - direction_and_amount

    print("Error:" + str(square_error) + " Prediction: " + str(neural_network_prediction))

# %% [markdown]
# ## Overcoming The Limitation of Gradient Descent
# - weight = 0.3
# - input_score = 2
# - ground_truth_prediction = 0.4
# - iteration in range(20)
# - alpha = 0.1
#
# ## Calculation of Gradient Descent
# - square_error = (neural_network_prediction - ground_truth_prediction ) ** 2
# - direction_and_amount = (neural_network_prediction - ground_truth_prediction ) * input
# - weight = weight - (alpha * direction_and_amount)

# %%
weight = 0.3
input_score = 2
ground_truth_prediction = 0.4
alpha = 0.1

for iteration in range(20):
    neural_network_prediction = input_score * weight
    square_error = (neural_network_prediction - ground_truth_prediction ) ** 2

    direction_and_amount = (neural_network_prediction - ground_truth_prediction ) * input_score
    weight = weight - (alpha * direction_and_amount)

    print("Error:" + str(square_error) + " Prediction: " + str(neural_network_prediction))
# Out:
# Error:0.03999999999999998 Prediction: 0.6
# Error:0.0144 Prediction: 0.52
# Error:0.005184000000000001 Prediction: 0.47200000000000003
# Error:0.0018662400000000014 Prediction: 0.44320000000000004
# Error:0.0006718464 Prediction: 0.42592
# Error:0.00024186470400000033 Prediction: 0.41555200000000003
# Error:8.70712934399997e-05 Prediction: 0.4093312
# Error:3.1345665638400016e-05 Prediction: 0.40559872
# Error:1.1284439629823931e-05 Prediction: 0.403359232
# Error:4.062398266736526e-06 Prediction: 0.4020155392
# Error:1.4624633760251225e-06 Prediction: 0.40120932352
# Error:5.264868153690119e-07 Prediction: 0.400725594112
# Error:1.895352535328636e-07 Prediction: 0.4004353564672
# Error:6.82326912718425e-08 Prediction: 0.40026121388032004
# Error:2.456376885786678e-08 Prediction: 0.40015672832819205
# Error:8.842956788836216e-09 Prediction: 0.40009403699691526
# Error:3.1834644439835434e-09 Prediction: 0.4000564221981492
# Error:1.1460471998340758e-09 Prediction: 0.4000338533188895
# ...
